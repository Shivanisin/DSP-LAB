# %%
# 1
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt


x1 = [5*np.sin(2*np.pi*t) for t in np.linspace(0,1, 1000)]

y2 = [7*np.sin(5*np.pi*t) for t in np.linspace(0,3, 1000)]

z3 = [9*np.sin(7*np.pi*t) for t in np.linspace(0,4, 1000)]

SAVM=[i+J+K for i,J,K in zip(x1,y2,z3)]

#plt.plot(SAVM)

S=np.fft.fft(SAVM)
#plt.plot(SAVM)
#print(SAVM)
plt.plot(abs(S[0]))
plt.plot(S)
plt.show()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#4 ques
import thinkdsp as t
import thinkplot as d
from IPython.display import Audio
wave1 = t.read_wave("Downloads/shi.wav")
wave1.plot()

x = wave.segment(start = 0, duration = 15)
aud = x.make_audio()
aud
spec = x.make_spectrum()
spec.plot()

# %%
# ques 5
import thinkdsp as d
from IPython.display import Audio
import thinkplot as t
from IPython.display import Audio
m=d.SinSignal(freq=521,amp=3,offset= 0)
n=d.SinSignal(freq=554,amp=3,offset=0)
o=d.SinSignal(freq=587,amp=4,offset=0)
p=d.SinSignal(freq=622,amp=5,offset=0)
q=d.SinSignal(freq=659,amp=5,offset=0)
r=d.SinSignal(freq=698,amp=5,offset=0)
s=d.SinSignal(freq=740,amp=5,offset=0)
t=d.SinSignal(freq=780,amp=5,offset=0)
u=d.SinSignal(freq=831,amp=5,offset=0)
v=d.SinSignal(freq=880,amp=5,offset=0)
w=d.SinSignal(freq=932,amp=5,offset=0)
x=d.SinSignal(freq=988,amp=5,offset=0)
y=d.SinSignal(freq=1047,amp=5,offset=0)
#r0=m+n+o+p
#r.plot()
m1=m.make_wave(duration=1,start=0,framerate=4000)
n1=n.make_wave(duration=1,start=0.5,framerate=4000)
o1=o.make_wave(duration=1,start=1,framerate=4000)
p1=p.make_wave(duration=1,start=1.5,framerate=4000)
q1=q.make_wave(duration=1,start=2,framerate=4000)
r1=r.make_wave(duration=1,start=2.5,framerate=4000)
s1=s.make_wave(duration=1,start=3,framerate=4000)
t1=t.make_wave(duration=1,start=3.5,framerate=4000)
u1=u.make_wave(duration=1,start=4,framerate=4000)
v1=v.make_wave(duration=1,start=4.5,framerate=4000)
w1=w.make_wave(duration=1,start=5,framerate=4000)
x1=x.make_wave(duration=1,start=5.5,framerate=4000)
y1=y.make_wave(duration=1,start=6,framerate=4000)
a= m1+n1+o1+p1+q1+r1+s1+t1+u1+v1+w1+x1+y1
b=Audio(data=a.ys,rate=a.framerate)
b
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
